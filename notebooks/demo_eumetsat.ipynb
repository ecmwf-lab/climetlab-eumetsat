# %%
#!pip install --quiet climetlab climetlab-eumetsat

# %%
from climetlab import load_source, plot_map

ds = load_source(
    "eumetsat-datastore",
    "EO:EUM:DAT:METOP:GLB-SST-NC",
    start_date="2016-07-23T17:58:00Z",
    end_date="2016-07-24T06:01:03Z",
)

# %%
ds.to_datetime_list()
# Out:
# [datetime.datetime(2016, 7, 23, 12, 0),
#  datetime.datetime(2016, 7, 24, 0, 0),
#  datetime.datetime(2016, 7, 24, 12, 0)]

# %%
ds.to_bounding_box().as_dict()
# Out:
# {'north': 89.974609375,
#  'west': -179.974609375,
#  'south': -89.974609375,
#  'east': 179.974609375}

# %%
plot_map(
    ds,
    style=dict(
        contour=False,
        contour_shade=True,
        contour_shade_colour_direction="clockwise",
        contour_shade_max_level_colour="magenta",
        contour_shade_min_level_colour="cyan",
        contour_shade_technique="cell_shading",
        contour_shade_cell_resolution=100,
    ),
)

# %%
ds.to_xarray()
# Out:
# <xarray.Dataset>
# Dimensions:                    (lat: 3600, lon: 7200, time: 3)
# Coordinates:
#   * time                       (time) datetime64[ns] 2016-07-23T12:00:00 ... ...
#   * lat                        (lat) float32 -89.97 -89.92 ... 89.92 89.97
#   * lon                        (lon) float32 -180.0 -179.9 ... 179.9 180.0
# Data variables: (12/14)
#     sea_surface_temperature    (time, lat, lon) float32 dask.array<chunksize=(1, 3600, 7200), meta=np.ndarray>
#     sst_dtime                  (time, lat, lon) timedelta64[ns] dask.array<chunksize=(1, 3600, 7200), meta=np.ndarray>
#     sses_bias                  (time, lat, lon) float32 dask.array<chunksize=(1, 3600, 7200), meta=np.ndarray>
#     sses_standard_deviation    (time, lat, lon) float32 dask.array<chunksize=(1, 3600, 7200), meta=np.ndarray>
#     dt_analysis                (time, lat, lon) float32 dask.array<chunksize=(1, 3600, 7200), meta=np.ndarray>
# ...
