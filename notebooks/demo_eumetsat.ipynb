# %%
#!pip install --quiet climetlab climetlab-eumetsat

# %%
from climetlab import load_source, plot_map

ds = load_source(
    "eumetsat-datastore",
    "EO:EUM:DAT:METOP:GLB-SST-NC",
    start_date="2016-07-24T00:00:00Z",
    end_date="2016-07-24T01:00:00Z",
)

plot_map(
    ds,
    style=dict(
        contour=False,
        contour_shade=True,
        contour_shade_colour_direction="clockwise",
        contour_shade_max_level_colour="magenta",
        contour_shade_min_level_colour="cyan",
        contour_shade_technique="cell_shading",
        contour_shade_cell_resolution=100,
    ),
)
# Out:
# {'format': 'json', 'pi': 'EO:EUM:DAT:METOP:GLB-SST-NC', 'dtstart': '2016-07-24T00:00:00Z', 'dtend': '2016-07-24T01:00:00Z', 'si': 0, 'c': 1000}
# COUNT 1
